# %% [markdown]
# >**Necessary Package Download**

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.3/614.3 kB 6.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Training on Custem Dataset**

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
#!yolo task=detect mode=train model=yolov8s.yaml data= config.yaml epochs=20 imgsz=640
#or


model = YOLO("yolov8s.pt")

model.train(data="/content/drive/MyDrive/Yolov8_dataset/config.yaml", epochs=10, imagsz=640)

# %% [markdown]
# **Validatiom**

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/Yolov8_dataset/runs/detect/train2/weights/best.pt data=/content/drive/MyDrive/Yolov8_dataset/config.yaml
# Out:
# Ultralytics YOLOv8.0.168 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients
# ...
# 100% 755k/755k [00:00<00:00, 16.4MB/s]
# val: Scanning /content/drive/MyDrive/Yolov8_dataset/valid/labels.cache... 88 images, 5 backgrounds, 0 corrupt: 100% 88/88 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 6/6 [01:25<00:00, 14.20s/it]
#                    all         88        117      0.591     0.0397     0.0335     0.0145
#                  angle         88         12          1          0     0.0113    0.00273
#               fracture         88         59       0.25      0.102     0.0496     0.0134
#                   line         88         35      0.113     0.0571     0.0652     0.0389
#        messed_up_angle         88         11          1          0    0.00781    0.00292
# ...

# %% [markdown]
# **Predictions on images folder**

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Yolov8_dataset/runs/detect/train2/weights/best.pt source=/content/drive/MyDrive/Yolov8_dataset/test/images
# Out:
# Ultralytics YOLOv8.0.168 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients
#
# image 1/44 /content/drive/MyDrive/Yolov8_dataset/test/images/105_jpg.rf.3cde2fcd15a9bdf6a2d2d32aff48f33d.jpg: 640x384 1 line, 420.0ms
# image 2/44 /content/drive/MyDrive/Yolov8_dataset/test/images/10_jpg.rf.d362a00f9a6b4ac31668dc8aae9c71de.jpg: 640x640 1 line, 658.0ms
# image 3/44 /content/drive/MyDrive/Yolov8_dataset/test/images/117_jpg.rf.119dccd2483b04d8d3a8c33a1393d362.jpg: 640x224 1 line, 239.0ms
# image 4/44 /content/drive/MyDrive/Yolov8_dataset/test/images/118_jpg.rf.acee2a86eba65adc57f3b15d5acab93c.jpg: 640x256 (no detections), 276.4ms
# image 5/44 /content/drive/MyDrive/Yolov8_dataset/test/images/11_jpg.rf.8e1c22ba2779121f3ba0a8ae03a20407.jpg: 640x384 (no detections), 371.2ms
# image 6/44 /content/drive/MyDrive/Yolov8_dataset/test/images/124_jpg.rf.100aeaede7a9c017d7f74f73cfcf34d7.jpg: 640x544 (no detections), 536.8ms
# ...

# %%
# !zip -r /content/file.zip /content/runs

# %%
from google.colab import files
files.download("/content/file.zip")

# %% [markdown]
# > **Single image Prediction**

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Yolov8_dataset/runs/detect/train2/weights/best.pt source=/content/1.jpg
# Out:
# Ultralytics YOLOv8.0.170 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients
#
# image 1/1 /content/1.jpg: 640x416 2 lines, 476.2ms
# Speed: 2.6ms preprocess, 476.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 416)
# Results saved to runs/detect/predict6

# %%
# !yolo export model= /content/drive/MyDrive/Yolov8_dataset/runs/detect/train2/weights/best.pt format=saved_model
# Out:
# Ultralytics YOLOv8.0.170 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients
#
# PyTorch: starting from '/content/drive/MyDrive/Yolov8_dataset/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (127.9 MB)
# requirements: Ultralytics requirements ['onnx', 'onnx2tf>=1.15.4', 'sng4onnx>=1.0.1', 'onnxsim>=0.4.33', 'onnx_graphsurgeon>=0.3.26', 'tflite_support', 'onnxruntime'] not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 40.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.1/382.1 kB 242.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 73.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 149.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # > Visualization

# %%
Image(filename = r'/content/drive/MyDrive/Yolov8_dataset/runs/detect/train2/labels.jpg', width=500)

# %%
Image(filename = r'/content/drive/MyDrive/Yolov8_dataset/runs/detect/train2/labels_correlogram.jpg', width=660)

# %%
Image(filename = r'/content/drive/MyDrive/Yolov8_dataset/runs/detect/train2/train_batch0.jpg', width=660)

# %% [markdown]
# **Visualition on Validation Dataset**

# %%
Image(filename = r'/content/F1_curve.png', width=660)

# %%
Image(filename = r'/content/P_curve.png', width=660)

# %%
Image(filename = r'/content/confusion_matrix.png', width=660)

# %%
Image(filename = r'/content/val_batch0_labels.jpg', width=660)
